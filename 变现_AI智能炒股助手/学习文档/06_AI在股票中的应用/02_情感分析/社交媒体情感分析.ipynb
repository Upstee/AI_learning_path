# %% [markdown]
# # 社交媒体情感分析
#
# ## 📋 概述
#
# 社交媒体情感分析是股票分析中的重要方法，通过分析社交媒体（微博、Twitter、股吧等）的情感倾向来预测市场情绪。本章节将详细介绍社交媒体情感分析的方法和应用。
#
# **学习方式**：本文件是Jupyter Notebook格式，你可以边看边运行代码，通过实际代码示例理解社交媒体情感分析。

# %%
# 导入库
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

print("环境准备完成！")

# %% [markdown]
# ## 📖 核心内容
#
# ### 1. 社交媒体情感分析概述
#
# 社交媒体情感分析是分析社交媒体平台上的用户评论和讨论，用于预测市场情绪。主要平台包括：
# - 微博
# - Twitter
# - 股吧
# - Reddit
#
# ### 2. 社交媒体情感分析示例
#
# 社交媒体情感分析需要考虑：
# - 用户情绪波动大
# - 信息传播速度快
# - 可能存在噪音数据
#
# ## 💡 关键要点总结
#
# 1. **数据来源**：微博、Twitter、股吧、Reddit
# 2. **特点**：情绪波动大、传播速度快
# 3. **应用场景**：市场情绪分析、股价预测
#
# ## 🔗 相关知识点
#
# - [文本情感分析](./文本情感分析.ipynb)
# - [新闻情感分析](./新闻情感分析.ipynb)
