# %% [markdown]
# # 市场效率分析
#
# ## 📚 学习目标
#
# - 理解市场效率的概念
# - 分析市场效率的影响因素
# - 评估股票市场的效率
# - 应用效率理论指导投资

# %% [markdown]
# ## 1. 市场效率的概念
#
# 市场效率是指市场能够快速、准确地反映信息，使价格接近真实价值的能力。

# %% [markdown]
# ## 2. 股票市场效率分析

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus'] = False

# 模拟市场效率：价格对信息的反应速度
time = np.arange(0, 20, 0.1)

# 高效市场：价格快速反应
efficient_market = 1 - np.exp(-time/2)

# 低效市场：价格缓慢反应
inefficient_market = 1 - np.exp(-time/8)

plt.figure(figsize=(12, 6))
plt.plot(time, efficient_market, 'g-', linewidth=2, label='高效市场')
plt.plot(time, inefficient_market, 'r--', linewidth=2, label='低效市场')
plt.xlabel('时间', fontsize=12)
plt.ylabel('价格反应程度', fontsize=12)
plt.title('市场效率：价格对信息的反应速度', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
