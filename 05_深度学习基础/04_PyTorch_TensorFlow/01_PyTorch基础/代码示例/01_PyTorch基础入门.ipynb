# %% [markdown]
# # PyTorch基础入门
#
# ## 📚 代码示例关联
#
# **本示例位置**：这是深度学习框架的第一个代码示例
#
# **基于**：
# - [从零实现前馈神经网络](../../01_神经网络基础/02_前馈神经网络/代码示例/01_从零实现前馈神经网络.ipynb) - 理解原理后，使用框架实现
# - [实现简单的自动梯度系统](../../01_神经网络基础/03_自动梯度与优化/代码示例/01_实现简单的自动梯度系统.ipynb) - 理解自动梯度原理
# - [从零实现神经元](../../01_神经网络基础/01_感知器与神经元/代码示例/01_从零实现神经元.ipynb) - 理解基本单元
#
# **扩展为**：
# - [CNN实现](../../02_CNN/代码示例/) - 使用PyTorch实现CNN
# - [RNN实现](../../03_RNN_LSTM/代码示例/) - 使用PyTorch实现RNN
# - [Transformer实现](../../06_注意力机制与外部记忆/02_Transformer架构/代码示例/) - 使用PyTorch实现Transformer
# - [综合实战项目](../../08_综合实战项目/) - 使用PyTorch完成项目
#
# **相关示例**：
# - [TensorFlow基础入门](../02_TensorFlow基础/代码示例/) - 另一个框架
# - [从零实现优化算法](../../05_网络优化与正则化/01_网络优化/代码示例/01_从零实现优化算法.ipynb) - 使用PyTorch的优化器
#
# ---
#
# 本示例将展示PyTorch的基础操作，包括：
# - 张量（Tensor）操作
# - 自动梯度（Autograd）
# - 构建简单神经网络
#
# **学习目标**：
# 1. 掌握PyTorch的基本操作
# 2. 理解自动梯度系统
# 3. 能够使用PyTorch构建和训练简单模型
