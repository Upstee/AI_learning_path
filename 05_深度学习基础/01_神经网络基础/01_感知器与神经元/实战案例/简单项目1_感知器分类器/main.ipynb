# %% [markdown]
# # 简单项目1：感知器分类器
#
# ## 项目目标
#
# 使用感知器实现一个简单的二分类器，解决线性可分的分类问题。
#
# ## 项目概述
#
# 本项目将：
# 1. 生成线性可分的二分类数据
# 2. 从零实现感知器
# 3. 训练感知器并可视化学习过程
# 4. 评估分类效果

# %%
# 导入必要的库
import numpy as np
import matplotlib.pyplot as plt

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
np.random.seed(42)

print("环境准备完成！")

# %% [markdown]
# ## 步骤1：实现感知器类
#
# 从零实现感知器，包含训练和预测功能。

# %%
# TODO: 在这里实现感知器类
# 参考代码示例中的实现
# 包含：__init__, fit, predict, score 方法

class Perceptron:
    """感知器类"""
    # TODO: 实现感知器类
    pass

print("感知器类定义完成！")

# %% [markdown]
# ## 步骤2：生成训练数据
#
# 生成线性可分的二分类数据。

# %%
# TODO: 生成线性可分的二分类数据
# 提示：使用np.random.randn生成两类数据，确保它们线性可分

# 可视化数据分布
# TODO: 绘制散点图，显示两类数据

print("数据准备完成！")

# %% [markdown]
# ## 步骤3：训练感知器
#
# 训练感知器并观察学习过程。

# %%
# TODO: 创建感知器实例并训练
# TODO: 可视化训练过程（错误数随迭代次数的变化）
# TODO: 计算训练准确率

print("训练完成！")

# %% [markdown]
# ## 步骤4：可视化结果
#
# 绘制决策边界和分类结果。

# %%
# TODO: 绘制决策边界
# 提示：决策边界方程 w1*x1 + w2*x2 + b = 0
# 即：x2 = -(w1*x1 + b) / w2

# TODO: 在图上显示数据点和决策边界

print("可视化完成！")

# %% [markdown]
# ## 总结
#
# 完成本项目后，你应该：
# 1. ✅ 理解感知器的基本工作原理
# 2. ✅ 能够从零实现感知器
# 3. ✅ 能够可视化感知器的学习过程
# 4. ✅ 理解线性决策边界
#
# ### 思考问题
#
# 1. 感知器为什么能解决这个分类问题？
# 2. 如果数据不是线性可分的，感知器会怎样？
# 3. 学习率对训练过程有什么影响？
