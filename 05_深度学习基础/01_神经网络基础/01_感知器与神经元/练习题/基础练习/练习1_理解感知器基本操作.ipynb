# %% [markdown]
# # 练习1：理解感知器的基本操作
#
# ## 练习目标
#
# 通过手动计算，深入理解感知器的工作原理。
#
# ## 任务说明
#
# 本练习要求你手动计算感知器的输出，理解每个步骤的含义。

# %%
import numpy as np

# 设置随机种子
np.random.seed(42)

print("环境准备完成！")

# %% [markdown]
# ## 任务1：手动计算感知器输出
#
# 给定：
# - 权重：$\mathbf{w} = [0.5, -0.3]$
# - 偏置：$b = 0.2$
# - 输入：$\mathbf{x} = [1, 2]$
#
# 计算感知器的输出。

# %%
# TODO: 定义权重、偏置和输入
# w = ?
# b = ?
# x = ?

# TODO: 计算加权和（净输入）
# z = w^T * x + b
# 提示：使用np.dot()计算点积

# TODO: 通过阶跃函数得到输出
# 如果z >= 0，输出1；否则输出0

# 打印结果
# print(f"加权和 z = {z:.4f}")
# print(f"输出 y = {y}")

# 验证：应该得到 z = 0.1, y = 1
