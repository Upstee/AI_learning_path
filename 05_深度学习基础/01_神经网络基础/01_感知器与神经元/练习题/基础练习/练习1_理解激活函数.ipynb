# %% [markdown]
# # 练习1：理解激活函数
#
# ## 练习目标
#
# 通过手动计算和可视化，深入理解不同激活函数的特性。
#
# ## 任务说明
#
# 本练习要求你：
# 1. 手动计算不同激活函数的输出
# 2. 理解激活函数的导数
# 3. 可视化激活函数

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

print("环境准备完成！")

# %% [markdown]
# ## 任务1：手动计算Sigmoid函数
#
# 给定输入 z = 0, z = 1, z = -1，计算Sigmoid函数的输出。
#
# 公式：σ(z) = 1 / (1 + e^(-z))

# %%
# TODO: 实现Sigmoid函数
# def sigmoid(z):
#     # 你的代码 here
#     pass

# TODO: 计算不同输入值的输出
# z_values = [0, 1, -1]
# for z in z_values:
#     output = sigmoid(z)
#     print(f"Sigmoid({z}) = {output:.4f}")

# 验证：Sigmoid(0)应该约等于0.5
