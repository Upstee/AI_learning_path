# %% [markdown]
# # Jupyter练习1：完整神经元训练流程
#
# ## 学习目标
#
# 通过本练习，你将完整地实现一个神经元的训练流程，包括：
# 1. 数据准备
# 2. 神经元实现
# 3. 训练过程
# 4. 评估和可视化
#
# ## 任务说明
#
# 本练习是一个综合性的实践项目，需要你完成所有TODO部分。

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

np.random.seed(42)
print("环境准备完成！")

# %% [markdown]
# ## 步骤1：数据准备
#
# TODO: 生成或加载一个二分类数据集

# %%
# TODO: 生成训练数据
# 提示：可以使用np.random生成线性可分的二分类数据
# X = ...
# y = ...

# %% [markdown]
# ## 步骤2：实现激活函数
#
# TODO: 实现Sigmoid激活函数及其导数

# %%
# TODO: 实现Sigmoid函数
# def sigmoid(z):
#     pass

# TODO: 实现Sigmoid的导数
# def sigmoid_derivative(z):
#     pass

# %% [markdown]
# ## 步骤3：实现神经元类
#
# TODO: 实现完整的Neuron类

# %%
# TODO: 实现Neuron类
# class Neuron:
#     def __init__(self, n_features):
#         pass
#     
#     def forward(self, X):
#         pass
#     
#     def backward(self, X, z, output, grad_output):
#         pass
#     
#     def update(self, grad_weights, grad_bias, learning_rate):
#         pass

# %% [markdown]
# ## 步骤4：训练神经元
#
# TODO: 实现训练循环

# %%
# TODO: 创建神经元实例
# neuron = Neuron(...)

# TODO: 实现训练循环
# for epoch in range(n_epochs):
#     # 前向传播
#     # 计算损失
#     # 反向传播
#     # 更新参数

# %% [markdown]
# ## 步骤5：评估和可视化
#
# TODO: 计算准确率并可视化结果

# %%
# TODO: 计算准确率
# predictions = ...
# accuracy = ...

# TODO: 可视化训练损失
# plt.plot(losses)

# TODO: 可视化决策边界
# 绘制数据点和决策边界

# %% [markdown]
# ## 总结
#
# 完成本练习后，你应该能够：
# 1. 理解神经元的完整训练流程
# 2. 实现前向传播和反向传播
# 3. 使用梯度下降训练神经元
# 4. 评估和可视化训练结果
#
# ### 思考问题
#
# 1. 学习率对训练有什么影响？尝试不同的学习率。
# 2. 如果数据不是线性可分的，会发生什么？
# 3. 如何改进训练过程？（提示：学习率衰减、正则化）
