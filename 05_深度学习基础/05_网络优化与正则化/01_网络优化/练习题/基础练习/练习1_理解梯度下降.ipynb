# %% [markdown]
# # 练习1：理解梯度下降
#
# ## 练习目标
#
# 通过手动计算和可视化，深入理解梯度下降的工作原理。
#
# ## 任务说明
#
# 本练习要求你：
# 1. 手动计算梯度
# 2. 实现梯度下降算法
# 3. 可视化优化过程

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

print("环境准备完成！")

# %% [markdown]
# ## 任务1：定义损失函数
#
# TODO: 定义一个简单的二次函数 f(x) = (x-3)^2，最优解在 x=3

# %%
# TODO: 实现损失函数
# def loss(x):
#     pass

# TODO: 实现梯度函数
# def gradient(x):
#     pass

# %% [markdown]
# ## 任务2：实现梯度下降
#
# TODO: 实现梯度下降算法

# %%
# TODO: 实现梯度下降
# def gradient_descent(x0, learning_rate, n_iterations):
#     x = x0
#     history = [x]
#     for i in range(n_iterations):
#         # 计算梯度
#         # 更新参数
#         # 记录历史
#     return x, history

# %% [markdown]
# ## 任务3：可视化优化过程
#
# TODO: 绘制损失函数和优化路径

# %%
# TODO: 可视化
# 1. 绘制损失函数曲线
# 2. 绘制优化路径
# 3. 标记起点和终点

# %% [markdown]
# ## 思考问题
#
# 1. 学习率对优化过程有什么影响？尝试不同的学习率。
# 2. 如果学习率太大，会发生什么？
# 3. 如果学习率太小，会发生什么？
