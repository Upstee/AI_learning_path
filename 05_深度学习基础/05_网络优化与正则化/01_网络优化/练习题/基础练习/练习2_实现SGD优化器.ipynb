# %% [markdown]
# # 练习2：实现SGD优化器
#
# ## 练习目标
#
# 通过从零实现SGD（随机梯度下降）优化器，深入理解其工作原理和特点。
#
# ## 任务说明
#
# 本练习要求你：
# 1. 理解SGD算法的数学原理
# 2. 从零实现SGD优化器类
# 3. 在简单优化问题上测试SGD
# 4. 对比不同学习率的效果
# 5. 理解SGD的优缺点
#
# ## 前置知识
#
# - 理解梯度下降的基本原理
# - 熟悉Python类和对象
# - 了解NumPy的基本操作
#
# ## 学习重点
#
# - SGD的更新公式：θ = θ - η * ∇θ
# - 学习率的选择和影响
# - SGD的优缺点分析

# %%
# 导入必要的库
import numpy as np
import matplotlib.pyplot as plt

# 设置中文字体，确保图表能正确显示中文
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 设置随机种子，确保结果可复现
np.random.seed(42)

print("环境准备完成！")
print("Python版本要求：3.7+")
print("主要依赖：numpy, matplotlib")

# %% [markdown]
# ## 任务1：理解SGD算法
#
# ### SGD算法原理
#
# **随机梯度下降（SGD）**是最基础的优化算法之一。其核心思想是：
#
# 1. **更新公式**：θ_{t+1} = θ_t - η * ∇_θ L(θ_t)
#    - θ_t：当前参数
#    - η：学习率（learning rate）
#    - ∇_θ L(θ_t)：损失函数关于参数的梯度
#
# 2. **特点**：
#    - 简单直接，易于实现
#    - 每次只使用一个样本（或小批量）的梯度
#    - 计算效率高，适合大规模数据
#
# 3. **优缺点**：
#    - ✅ 优点：简单、内存占用小、适合在线学习
#    - ❌ 缺点：收敛慢、容易震荡、对学习率敏感
#
# ### 任务要求
#
# TODO: 阅读并理解上述SGD原理，思考以下问题：
# 1. 为什么SGD叫"随机"梯度下降？
# 2. 学习率η的作用是什么？
# 3. 学习率太大或太小会有什么问题？

# %% [markdown]
# ## 任务2：实现SGD优化器类
#
# ### 实现要求
#
# TODO: 实现一个完整的SGD优化器类，包含以下功能：
#
# 1. **初始化方法（__init__）**：
#    - 接收学习率参数
#    - 保存学习率
#
# 2. **更新方法（update）**：
#    - 接收当前参数和梯度
#    - 根据SGD公式更新参数
#    - 返回更新后的参数
#
# ### 提示
#
# - 参数和梯度都是NumPy数组
# - 更新公式：`params = params - learning_rate * grads`
# - 注意数组的广播规则

# %%
# TODO: 实现SGD优化器类
class SGD:
    """
    随机梯度下降优化器
    
    参数:
        learning_rate (float): 学习率，控制每次更新的步长
    """
    def __init__(self, learning_rate=0.01):
        """
        初始化SGD优化器
        
        参数:
            learning_rate: 学习率，默认0.01
        """
        # TODO: 保存学习率参数
        # self.lr = ...
        pass
    
    def update(self, params, grads):
        """
        更新参数
        
        参数:
            params (numpy.ndarray): 当前参数值
            grads (numpy.ndarray): 梯度值
        
        返回:
            numpy.ndarray: 更新后的参数值
        """
        # TODO: 实现SGD更新公式
        # params = params - self.lr * grads
        # return params
        pass

# %% [markdown]
# ## 任务3：定义测试问题
#
# ### 测试函数：Rosenbrock函数
#
# 我们将使用经典的Rosenbrock函数来测试SGD优化器：
#
# **Rosenbrock函数**：f(x, y) = (a - x)² + b * (y - x²)²
# - 全局最小值在 (a, a²) 处，值为 0
# - 这里我们设置 a=1, b=100
# - 最优解在 (1, 1) 处
#
# 这个函数的特点是有一个狭窄的"山谷"，对优化算法有挑战性。
#
# ### 任务要求
#
# TODO: 实现损失函数和梯度函数

# %%
# TODO: 定义Rosenbrock损失函数
def loss_function(params):
    """
    计算Rosenbrock函数的损失值
    
    参数:
        params (numpy.ndarray): 参数 [x, y]
    
    返回:
        float: 损失值
    """
    # TODO: 实现损失函数
    # a, b = 1, 100
    # x, y = params[0], params[1]
    # return (a - x)**2 + b * (y - x**2)**2
    pass

# TODO: 定义梯度函数
def compute_gradients(params):
    """
    计算Rosenbrock函数的梯度
    
    参数:
        params (numpy.ndarray): 参数 [x, y]
    
    返回:
        numpy.ndarray: 梯度 [df/dx, df/dy]
    """
    # TODO: 实现梯度计算
    # a, b = 1, 100
    # x, y = params[0], params[1]
    # df_dx = -2 * (a - x) - 4 * b * x * (y - x**2)
    # df_dy = 2 * b * (y - x**2)
    # return np.array([df_dx, df_dy])
    pass

# %% [markdown]
# ## 任务4：使用SGD优化器训练
#
# ### 训练流程
#
# 1. 初始化参数（从远离最优解的位置开始）
# 2. 创建SGD优化器
# 3. 迭代训练：
#    - 计算梯度
#    - 使用优化器更新参数
#    - 记录损失和参数历史
# 4. 可视化训练过程
#
# ### 任务要求
#
# TODO: 实现完整的训练循环

# %%
# TODO: 初始化参数（从远离最优解的位置开始，便于观察优化过程）
# params = np.array([-1.5, 2.0])

# TODO: 创建SGD优化器，学习率设置为0.001
# optimizer = SGD(learning_rate=0.001)

# TODO: 设置训练参数
# n_epochs = 1000  # 迭代次数

# TODO: 记录训练过程
# losses = []  # 记录每次迭代的损失值
# params_history = [params.copy()]  # 记录参数变化历史

# TODO: 训练循环
# for epoch in range(n_epochs):
#     # 1. 计算梯度
#     # grads = compute_gradients(params)
#     
#     # 2. 使用优化器更新参数
#     # params = optimizer.update(params, grads)
#     
#     # 3. 计算并记录损失
#     # loss = loss_function(params)
#     # losses.append(loss)
#     # params_history.append(params.copy())
#     
#     # 4. 每200次迭代打印一次进度
#     # if (epoch + 1) % 200 == 0:
#     #     print(f"Epoch {epoch+1}/{n_epochs}, Loss: {loss:.6f}, Params: [{params[0]:.4f}, {params[1]:.4f}]")

# print("训练完成！")

# %% [markdown]
# ## 任务5：可视化优化过程
#
# ### 可视化内容
#
# 1. **损失曲线**：展示损失值随迭代次数的变化
# 2. **优化路径**：在等高线图上展示参数的变化路径
# 3. **收敛分析**：分析优化过程的收敛情况
#
# ### 任务要求
#
# TODO: 实现完整的可视化代码

# %%
# TODO: 绘制损失曲线
# plt.figure(figsize=(12, 5))
# 
# plt.subplot(1, 2, 1)
# plt.plot(losses, label='SGD', linewidth=2)
# plt.xlabel('迭代次数')
# plt.ylabel('损失值')
# plt.title('SGD优化损失曲线')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.yscale('log')  # 使用对数刻度，便于观察

# TODO: 绘制优化路径（等高线图）
# plt.subplot(1, 2, 2)
# # 创建等高线图
# x = np.linspace(-2, 2, 100)
# y = np.linspace(-1, 3, 100)
# X, Y = np.meshgrid(x, y)
# Z = np.zeros_like(X)
# for i in range(X.shape[0]):
#     for j in range(X.shape[1]):
#         Z[i, j] = loss_function(np.array([X[i, j], Y[i, j]]))
# 
# # 绘制等高线
# contour = plt.contour(X, Y, Z, levels=20, alpha=0.5)
# plt.clabel(contour, inline=True, fontsize=8)
# 
# # 绘制优化路径
# params_history = np.array(params_history)
# plt.plot(params_history[:, 0], params_history[:, 1], 'o-', 
#          label='优化路径', markersize=3, alpha=0.6, linewidth=1.5)
# 
# # 标记起点和终点
# plt.plot(params_history[0, 0], params_history[0, 1], 'ko', 
#          markersize=10, label='起点')
# plt.plot(1, 1, 'r*', markersize=15, label='最优解 (1, 1)')
# 
# plt.xlabel('x')
# plt.ylabel('y')
# plt.title('SGD优化路径可视化')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.axis('equal')
# 
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 任务6：对比不同学习率的效果
#
# ### 实验目标
#
# 通过对比不同学习率（0.0001, 0.001, 0.01, 0.1）的效果，深入理解学习率对SGD的影响。
#
# ### 任务要求
#
# TODO: 使用不同的学习率训练，并对比结果

# %%
# TODO: 测试不同学习率
# learning_rates = [0.0001, 0.001, 0.01, 0.1]
# n_epochs = 500
# 
# results = {}  # 存储每个学习率的结果
# 
# for lr in learning_rates:
#     print(f"\n测试学习率: {lr}")
#     params = np.array([-1.5, 2.0])
#     optimizer = SGD(learning_rate=lr)
#     losses = []
#     
#     for epoch in range(n_epochs):
#         grads = compute_gradients(params)
#         params = optimizer.update(params, grads)
#         loss = loss_function(params)
#         losses.append(loss)
#     
#     results[lr] = {
#         'losses': losses,
#         'final_loss': losses[-1],
#         'final_params': params
#     }
#     print(f"  最终损失: {losses[-1]:.6f}")
#     print(f"  最终参数: [{params[0]:.4f}, {params[1]:.4f}]")

# TODO: 可视化对比
# plt.figure(figsize=(12, 5))
# 
# plt.subplot(1, 2, 1)
# colors = ['blue', 'green', 'orange', 'red']
# for i, lr in enumerate(learning_rates):
#     plt.plot(results[lr]['losses'], label=f'LR={lr}', 
#              color=colors[i], alpha=0.7, linewidth=2)
# plt.xlabel('迭代次数')
# plt.ylabel('损失值')
# plt.title('不同学习率的损失曲线对比')
# plt.legend()
# plt.grid(True, alpha=0.3)
# plt.yscale('log')
# 
# plt.subplot(1, 2, 2)
# # 绘制最终损失对比
# final_losses = [results[lr]['final_loss'] for lr in learning_rates]
# plt.bar(range(len(learning_rates)), final_losses, 
#         color=colors, alpha=0.7)
# plt.xlabel('学习率')
# plt.ylabel('最终损失值')
# plt.title('不同学习率的最终损失对比')
# plt.xticks(range(len(learning_rates)), learning_rates)
# plt.grid(True, alpha=0.3, axis='y')
# plt.yscale('log')
# 
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 总结与思考
#
# ### 关键知识点回顾
#
# 1. **SGD更新公式**：θ = θ - η * ∇θ
# 2. **学习率的作用**：控制每次更新的步长
# 3. **学习率的选择**：
#    - 太小：收敛慢
#    - 太大：可能震荡或不收敛
#    - 适中：平衡收敛速度和稳定性
#
# ### 思考问题
#
# 1. **为什么SGD叫"随机"梯度下降？**
#    - 提示：思考批量梯度下降、随机梯度下降、小批量梯度下降的区别
#
# 2. **学习率对优化过程有什么影响？**
#    - 从你的实验结果中总结规律
#
# 3. **如何选择合适的学习率？**
#    - 有什么经验法则或方法？
#
# 4. **SGD的优缺点是什么？**
#    - 在什么场景下适合使用SGD？
#
# ### 扩展任务
#
# - 尝试实现学习率衰减策略
# - 对比SGD与批量梯度下降的区别
# - 研究SGD的收敛性理论
#
# ---
#
# **完成本练习后，你将深入理解SGD优化器的工作原理！** 🎉
