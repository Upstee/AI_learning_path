# %% [markdown]
# # 线性回归完整学习流程
#
# ## 学习目标
#
# 通过本notebook，你将完成线性回归的完整学习流程：
# 1. 理解线性回归的理论基础
# 2. 从零实现线性回归算法
# 3. 使用scikit-learn实现线性回归
# 4. 评估和优化模型
# 5. 应用到实际问题
#
# ## 课程概述
#
# 本notebook是线性回归模块的综合练习，将带你从理论到实践，完整掌握线性回归。

# %% [markdown]
# ## 第一部分：理论回顾
#
# ### 线性回归的基本概念
#
# 线性回归是机器学习中最基础的算法之一，用于预测连续值。
#
# **核心思想**：找到一条直线（或超平面）来拟合数据，使得预测值与真实值之间的误差最小。
#
# **数学形式**：
# $$y = w_1 x_1 + w_2 x_2 + ... + w_n x_n + b$$
#
# **损失函数**（均方误差）：
# $$MSE = \frac{1}{m}\sum_{i=1}^{m}(y_i - \hat{y}_i)^2$$
#
# **优化目标**：最小化MSE

# %% [markdown]
# ## 第二部分：环境准备
#
# 导入必要的库和设置环境。

# %%
# 导入必要的库
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as SklearnLinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei', 'Arial Unicode MS', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# 设置随机种子
np.random.seed(42)

# 设置matplotlib在notebook中内联显示
# %matplotlib inline

print("环境准备完成！")
# Out:
# 环境准备完成！

# %% [markdown]
# ## 第三部分：数据准备
#
# ### 任务1：生成模拟数据
#
# **你的任务**：生成一个线性关系的数据集，真实关系为 y = 3*x + 2，加上一些噪声。
#
# **提示**：
# - 使用 `np.random.randn()` 生成随机数据
# - 添加噪声使数据更真实
# - 可视化数据，观察线性关系

# %%
# TODO: 在这里生成模拟数据
# 提示：
# 1. 生成X数据：使用 np.random.randn(n_samples, 1) * 10
# 2. 生成y数据：y = 3 * X.flatten() + 2 + 噪声
# 3. 噪声：np.random.randn(n_samples) * noise_level

# 你的代码：
# X = ...
# y = ...

# 可视化数据
# plt.scatter(X, y, alpha=0.5)
# plt.xlabel('X')
# plt.ylabel('y')
# plt.title('数据分布')
# plt.show()

# %% [markdown]
# ## 第四部分：从零实现线性回归
#
# ### 任务2：实现线性回归类
#
# **你的任务**：实现一个简单的线性回归类，使用最小二乘法。
#
# **提示**：
# - 使用公式：$\theta = (X^T X)^{-1} X^T y$
# - 记得添加偏置项（在X前加一列1）
# - 实现 `fit()` 和 `predict()` 方法

# %%
class MyLinearRegression:
    """从零实现的线性回归类"""
    
    def __init__(self):
        """初始化模型"""
        self.w = None  # 权重
        self.b = None  # 偏置
    
    def fit(self, X, y):
        """
        训练模型（使用最小二乘法）
        
        参数:
        - X: 特征数据 (m, n)
        - y: 目标值 (m,)
        """
        # TODO: 实现最小二乘法
        # 提示：
        # 1. 添加偏置项：X_bias = np.hstack([np.ones((m, 1)), X])
        # 2. 计算参数：theta = np.linalg.pinv(X_bias.T @ X_bias) @ X_bias.T @ y
        # 3. 分离偏置和权重：self.b = theta[0], self.w = theta[1:]
        
        # 你的代码：
        pass
    
    def predict(self, X):
        """
        预测
        
        参数:
        - X: 特征数据
        
        返回:
        - y_pred: 预测值
        """
        # TODO: 实现预测
        # 提示：y_pred = X @ self.w + self.b
        
        # 你的代码：
        pass

# 测试你的实现
# model = MyLinearRegression()
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
# print(f"MSE: {mean_squared_error(y_test, y_pred):.4f}")

# %% [markdown]
# ## 第五部分：使用scikit-learn
#
# ### 任务3：使用scikit-learn实现线性回归
#
# **你的任务**：使用scikit-learn的LinearRegression类训练模型，并对比自己实现的结果。

# %%
# TODO: 使用scikit-learn实现线性回归
# 提示：
# 1. 创建模型：model = SklearnLinearRegression()
# 2. 训练模型：model.fit(X_train, y_train)
# 3. 预测：y_pred = model.predict(X_test)
# 4. 评估：计算MSE和R²

# 你的代码：
# model_sklearn = ...
# model_sklearn.fit(...)
# y_pred_sklearn = ...
# mse_sklearn = ...
# r2_sklearn = ...

# print(f"scikit-learn结果:")
# print(f"  MSE: {mse_sklearn:.4f}")
# print(f"  R²: {r2_sklearn:.4f}")

# %% [markdown]
# ## 第六部分：模型评估
#
# ### 任务4：评估模型性能
#
# **你的任务**：计算并可视化模型的评估指标。
#
# **评估指标**：
# - MSE（均方误差）
# - MAE（平均绝对误差）
# - R²（决定系数）

# %%
# TODO: 评估模型性能
# 提示：
# 1. 计算MSE、MAE、R²
# 2. 可视化预测结果
# 3. 绘制残差图

# 你的代码：
# 计算评估指标
# mse = ...
# mae = ...
# r2 = ...

# 可视化
# fig, axes = plt.subplots(1, 2, figsize=(14, 5))
# 
# # 左图：预测值 vs 真实值
# axes[0].scatter(y_test, y_pred, alpha=0.5)
# axes[0].plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
# axes[0].set_xlabel('真实值')
# axes[0].set_ylabel('预测值')
# axes[0].set_title('预测值 vs 真实值')
# 
# # 右图：残差图
# residuals = y_test - y_pred
# axes[1].scatter(y_pred, residuals, alpha=0.5)
# axes[1].axhline(y=0, color='r', linestyle='--')
# axes[1].set_xlabel('预测值')
# axes[1].set_ylabel('残差')
# axes[1].set_title('残差图')
# 
# plt.tight_layout()
# plt.show()

# %% [markdown]
# ## 第七部分：总结与思考
#
# ### 完成情况检查
#
# - [ ] 成功生成模拟数据
# - [ ] 从零实现线性回归类
# - [ ] 使用scikit-learn实现线性回归
# - [ ] 评估模型性能
# - [ ] 可视化结果
#
# ### 思考问题
#
# 1. **最小二乘法和梯度下降有什么区别？**
#    - 什么时候用最小二乘法？
#    - 什么时候用梯度下降？
#
# 2. **如何判断模型是否过拟合？**
#    - 训练集和测试集的误差差异
#    - 如何防止过拟合？
#
# 3. **如何改进模型性能？**
#    - 特征工程
#    - 正则化
#    - 数据预处理
#
# ### 下一步学习
#
# - 学习正则化（L1、L2）
# - 学习多项式回归
# - 学习多特征线性回归
# - 应用到真实数据集
#
# ---
#
# **恭喜完成线性回归的完整学习流程！** 🎉
