# %% [markdown]
# # 进阶练习1：完整分类系统
#
# ## 练习目标
#
# 构建一个完整的分类系统，包括数据预处理、特征工程、模型训练、评估和优化。
#
# ## 练习要求
#
# ### 1. 数据加载与探索
# - 加载真实数据集
# - 进行数据探索（EDA）
# - 分析数据分布和类别平衡
#
# ### 2. 数据预处理
# - 处理缺失值
# - 特征编码（类别特征）
# - 特征标准化
#
# ### 3. 特征工程
# - 创建新特征
# - 特征选择
# - 特征变换
#
# ### 4. 模型训练与优化
# - 训练基础模型
# - 使用交叉验证
# - 超参数调优
#
# ### 5. 模型评估
# - 多种评估指标
# - 可视化结果
# - 特征重要性分析
